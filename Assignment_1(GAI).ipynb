# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52465/Generative-AI-2025/blob/main/Assignment_1(GAI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1=pd.read_excel("/content/Assignment-1_Data-1.xlsx")
d2=pd.read_excel("/content/Assignment-1_Data-2.xlsx")

# %%
d1
# Out:
#    Yactual  YPred
# 0       20   20.5
# 1       30   30.3
# 2       40   40.2
# 3       50   50.6
# 4       60   60.7

# %%
d2
# Out:
#    YActual  YPred  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0        0      0           1           1           2           0
# 1        0      0           1           0           2           0
# 2        0      1           1           2           2           1
# 3        0      2           1           0           2           2
# 4        0      2           1           2           2           2

# %% [markdown]
# ##Question-1

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
measured=np.array(d1['Yactual'])
predicted=np.array(d1['YPred'])
mse=mean_squared_error(measured,predicted)
rmse=np.sqrt(mse)
mape=np.mean(np.abs((measured-predicted)/measured))*100
r2=r2_score(measured,predicted)
mae=np.mean(np.abs(measured-predicted))
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Square Error (MSE): {mse}")
print(f"Root Mean Square Error (RMSE): {rmse}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Absolute Error (MAE): 0.4600000000000016
# Mean Square Error (MSE): 0.24600000000000147
# Root Mean Square Error (RMSE): 0.49598387070549127
# Mean Absolute Percentage Error (MAPE): 1.273333333333337%
# R-squared (R²): 0.99877

# %% [markdown]
# ##Question-2

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
measured=np.array(d2['YActual'])
predicted=np.array(d2['YPred'])
mse1=mean_squared_error(measured, predicted)
rmse1=np.sqrt(mse)
r2_1=r2_score(measured, predicted)
mae1=np.mean(np.abs(measured-predicted))
print(f"Mean Absolute Error (MAE): {mae1}")
print(f"Mean Square Error (MSE): {mse1}")
print(f"Root Mean Square Error (RMSE): {rmse1}")
print(f"R-squared (R²): {r2_1}")
# Out:
# Mean Absolute Error (MAE): 1.0
# Mean Square Error (MSE): 1.8
# Root Mean Square Error (RMSE): 1.3416407864998738
# R-squared (R²): 0.0
